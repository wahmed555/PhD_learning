# %% [markdown]
# # Merging DataFrame

# %% [markdown]
# ## Querying 1D series Data Structure and 2D (DataFrame) Data Structure
# ### using Loc or iloc for Row querying and square brackets[ ] on object itself for Column based Query
# we can query a DataFrame in Series using Boolean masking
# -Boolean masking is a powerful filtering method whic allows us to use broadcasting to determine what data shold be kepth in our analysis

# %%
import pandas as pd

purchase_1=pd.Series({'Name':'chris',
                      'item_purschased':'Dog food',
                     'cost':22.50})
purchase_2=pd.Series({'Name':'Keyvn',
                      'item_purschased':'kitty litter',
                     'cost':2.50})
purchase_3=pd.Series({'Name':'Vinod',
                      'item_purschased':'bird seed',
                     'cost':5.0})
df=pd.DataFrame([purchase_1,purchase_2,purchase_3],index=['Store 1','Store 2','Store 3'])
df
# Out:
#           Name item_purschased  cost
# Store 1  chris        Dog food  22.5
# Store 2  Keyvn    kitty litter   2.5
# Store 3  Vinod       bird seed   5.0

# %% [markdown]
# ## Adding Horizontally by using the column name and default scaler value

# %%
df['Delivered']=True
df
# Out:
#           Name item_purschased  cost  Delivered
# Store 1  chris        Dog food  22.5       True
# Store 2  Keyvn    kitty litter   2.5       True
# Store 3  Vinod       bird seed   5.0       True

# %% [markdown]
# ## Adding Horizontally by using the column name and different values in a Series but the list must be of same length as of dataFrame.

# %%
df['Date']=['December 1','January 1','Mid May']

df
# Out:
#           Name item_purschased  cost  Delivered        Date
# Store 1  chris        Dog food  22.5       True  December 1
# Store 2  Keyvn    kitty litter   2.5       True   January 1
# Store 3  Vinod       bird seed   5.0       True     Mid May

# %%
df['Sery']=pd.Series({'Name':'Vinod',
                      'item_purschased':'bird seed',
                     'cost':5.0})
df
# Out:
#           Name item_purschased  cost  Delivered        Date Sery
# Store 1  chris        Dog food  22.5       True  December 1  NaN
# Store 2  Keyvn    kitty litter   2.5       True   January 1  NaN
# Store 3  Vinod       bird seed   5.0       True     Mid May  NaN

# %% [markdown]
# ## Adding  Series with lenght less than length of DatFrame
#
# ### 1) we have to Manually enter None or NaN where value is missing
# ### 2) We have to pass a Dictionary as Series  such that keys of dictionary  mathching index of DatFrame will  help placing value at desired indices and missing will be left to NaN

# %%
adf=df.reset_index()
adf
# Out:
#      index   Name item_purschased  cost  Delivered        Date Sery
# 0  Store 1  chris        Dog food  22.5       True  December 1  NaN
# 1  Store 2  Keyvn    kitty litter   2.5       True   January 1  NaN
# 2  Store 3  Vinod       bird seed   5.0       True     Mid May  NaN

# %%
adf['Date']=pd.Series({0:'December 1',2:'Mid May'})
adf
# Out:
#      index   Name item_purschased  cost  Delivered        Date Sery
# 0  Store 1  chris        Dog food  22.5       True  December 1  NaN
# 1  Store 2  Keyvn    kitty litter   2.5       True         NaN  NaN
# 2  Store 3  Vinod       bird seed   5.0       True     Mid May  NaN

# %% [markdown]
# ## Adding Horizontally by using the column name and a scaller value

# %%
df=df.append(pd.Series(data={'Cost':3.00,'Item Purchased':'Kitty Food'},name=('Store 4')))
df
# Out:
#           Name item_purschased  cost  Delivered        Date Sery  Cost  \
# Store 1  chris        Dog food  22.5        1.0  December 1  NaN   NaN
# Store 2  Keyvn    kitty litter   2.5        1.0   January 1  NaN   NaN
# Store 3  Vinod       bird seed   5.0        1.0     Mid May  NaN   NaN
# Store 4    NaN             NaN   NaN        NaN         NaN  NaN   3.0
#
#         Item Purchased
# Store 1            NaN
# Store 2            NaN
# Store 3            NaN
# Store 4     Kitty Food

# %% [markdown]
# ##  c) Merging two DataFrame
#
# ### 1)  Union = Outer Join
# ### 2) Intersection= Inner Join

# %%
# Creating Two dataframes  with Name Column as its index

staff_df=pd.DataFrame([{'Name':'Kelly','Role':'Director HR'},
                 {'Name':'Sally','Role':'Course Liasion'},
                 {'Name':'James','Role':'Grader'}])
staff_df.set_index('Name')

student_df=pd.DataFrame([{'Name':'James','School':'Director HR'},
                 {'Name':'Mike','School':'Law'},
                 {'Name':'Sally','School':'Engineering'}])
student_df.set_index('Name')

print(staff_df)
print("\n")
print(student_df)
# Out:
#     Name            Role
# 0  Kelly     Director HR
# 1  Sally  Course Liasion
# 2  James          Grader
#
#
#     Name       School
# 0  James  Director HR
# 1   Mike          Law
# 2  Sally  Engineering

# %% [markdown]
# ## 1) Merge using Outer joint or Union

# %%
pd.merge(staff_df,student_df, how='outer',left_index=True,right_index=True)
# Out:
#   Name_x            Role Name_y       School
# 0  Kelly     Director HR  James  Director HR
# 1  Sally  Course Liasion   Mike          Law
# 2  James          Grader  Sally  Engineering

# %%
pd.merge(staff_df,student_df, how='outer')
# Out:
#     Name            Role       School
# 0  Kelly     Director HR          NaN
# 1  Sally  Course Liasion  Engineering
# 2  James          Grader  Director HR
# 3   Mike             NaN          Law

# %% [markdown]
# ## 2) Intersection using inner joint

# %%
pd.merge(staff_df,student_df, how='inner')
# Out:
#     Name            Role       School
# 0  Sally  Course Liasion  Engineering
# 1  James          Grader  Director HR

# %%
pd.merge(staff_df,student_df, how='inner',left_index=True,right_index=True)
# Out:
#   Name_x            Role Name_y       School
# 0  Kelly     Director HR  James  Director HR
# 1  Sally  Course Liasion   Mike          Law
# 2  James          Grader  Sally  Engineering

# %% [markdown]
# ## d) Merge only Staff who may be students also

# %%
pd.merge(staff_df,student_df,how='left')
# Out:
#     Name            Role       School
# 0  Kelly     Director HR          NaN
# 1  Sally  Course Liasion  Engineering
# 2  James          Grader  Director HR

# %% [markdown]
# ### e) Merge only who are student or may be staff also

# %%
pd.merge(staff_df,student_df,how='right')
# Out:
#     Name            Role       School
# 0  Sally  Course Liasion  Engineering
# 1  James          Grader  Director HR
# 2   Mike             NaN          Law

# %%
products_df=pd.DataFrame([{'Product ID':'4109','Price':5.0,'Product':'Sushi Roll'},
                          {'Product ID':'1412','Price':0.5,'Product':'Egg'},
                          {'Product ID':'8931','Price':1.5,'Product':'Bagel'}])
products_df.set_index('Product ID')

invoices_df=pd.DataFrame([{'Customer':'Ali','Product ID':'4109','Quantity':1},
                          {'Customer':'Eric','Product ID':'1412','Quantity':12},
                          {'Customer':'Ande','Product ID':'8931','Quantity':6},
                          {'Customer':'Sam','Product ID':'4109','Quantity':2}])
invoices_df.set_index('Product ID')
# Out:
#            Customer  Quantity
# Product ID
# 4109            Ali         1
# 1412           Eric        12
# 8931           Ande         6
# 4109            Sam         2

# %%
invoices_df
# Out:
#   Customer Product ID  Quantity
# 0      Ali       4109         1
# 1     Eric       1412        12
# 2     Ande       8931         6
# 3      Sam       4109         2

# %%
products_df
# Out:
#    Price     Product Product ID
# 0    5.0  Sushi Roll       4109
# 1    0.5         Egg       1412
# 2    1.5       Bagel       8931

# %%
df0=pd.merge(invoices_df,products_df,how='outer')
df0
# Out:
#   Customer Product ID  Quantity  Price     Product
# 0      Ali       4109         1    5.0  Sushi Roll
# 1      Sam       4109         2    5.0  Sushi Roll
# 2     Eric       1412        12    0.5         Egg
# 3     Ande       8931         6    1.5       Bagel

# %%
df0['Sum Price']=df0['Quantity']*df0['Price']
df0
# Out:
#   Customer Product ID  Quantity  Price     Product  Sum Price
# 0      Ali       4109         1    5.0  Sushi Roll        5.0
# 1      Sam       4109         2    5.0  Sushi Roll       10.0
# 2     Eric       1412        12    0.5         Egg        6.0
# 3     Ande       8931         6    1.5       Bagel        9.0

# %%
df0['Sum Price'].sum()
# Out:
# 30.0

# %%
# solution
print(pd.merge(products_df, invoices_df, left_index=True, right_on='Product ID'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-0cec90ebdc37> in <module>()
#       2
#       3 # solution
# ----> 4 print(pd.merge(products_df, invoices_df, left_index=True, right_on='Product ID'))
#
# C:\ProgramData\Anaconda6\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
#      59                          copy=copy, indicator=indicator,
# ---> 60                          validate=validate)
#      61     return op.get_result()
#      62
#
# C:\ProgramData\Anaconda6\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %% [markdown]
# # Pandas Idiom : Making code pandorable

# %% [markdown]
# ## Chain indexing

# %%
import pandas as pd
df=pd.read_csv('census.csv')

# %%
df.head()
df.set_index('STNAME')
# Out:
#            SUMLEV  REGION  DIVISION  STATE  COUNTY             CTYNAME  \
# STNAME
# Alabama        40       3         6      1       0             Alabama
# Alabama        50       3         6      1       1      Autauga County
# Alabama        50       3         6      1       3      Baldwin County
# Alabama        50       3         6      1       5      Barbour County
# Alabama        50       3         6      1       7         Bibb County
# Alabama        50       3         6      1       9       Blount County
# Alabama        50       3         6      1      11      Bullock County
# Alabama        50       3         6      1      13       Butler County
# Alabama        50       3         6      1      15      Calhoun County
# Alabama        50       3         6      1      17     Chambers County
# Alabama        50       3         6      1      19     Cherokee County
# Alabama        50       3         6      1      21      Chilton County
# ...

# %%
df.loc["Washtenaw"]["Total Population"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda6\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# C:\ProgramData\Anaconda6\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [Washtenaw] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-1e6c48eb8bf2> in <module>()
# ----> 1 df.loc["Washtenaw"]["Total Population"]
#
# ...

# %% [markdown]
# ## Chaining Method

# %%
(df.where(df['SUMLEV']==50))
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0        NaN     NaN       NaN    NaN     NaN        NaN                 NaN
# 1       50.0     3.0       6.0    1.0     1.0    Alabama      Autauga County
# 2       50.0     3.0       6.0    1.0     3.0    Alabama      Baldwin County
# 3       50.0     3.0       6.0    1.0     5.0    Alabama      Barbour County
# 4       50.0     3.0       6.0    1.0     7.0    Alabama         Bibb County
# 5       50.0     3.0       6.0    1.0     9.0    Alabama       Blount County
# 6       50.0     3.0       6.0    1.0    11.0    Alabama      Bullock County
# 7       50.0     3.0       6.0    1.0    13.0    Alabama       Butler County
# 8       50.0     3.0       6.0    1.0    15.0    Alabama      Calhoun County
# 9       50.0     3.0       6.0    1.0    17.0    Alabama     Chambers County
# 10      50.0     3.0       6.0    1.0    19.0    Alabama     Cherokee County
# ...

# %%
(df.where(df['SUMLEV']==50)).dropna()
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1       50.0     3.0       6.0    1.0     1.0    Alabama      Autauga County
# 2       50.0     3.0       6.0    1.0     3.0    Alabama      Baldwin County
# 3       50.0     3.0       6.0    1.0     5.0    Alabama      Barbour County
# 4       50.0     3.0       6.0    1.0     7.0    Alabama         Bibb County
# 5       50.0     3.0       6.0    1.0     9.0    Alabama       Blount County
# 6       50.0     3.0       6.0    1.0    11.0    Alabama      Bullock County
# 7       50.0     3.0       6.0    1.0    13.0    Alabama       Butler County
# 8       50.0     3.0       6.0    1.0    15.0    Alabama      Calhoun County
# 9       50.0     3.0       6.0    1.0    17.0    Alabama     Chambers County
# 10      50.0     3.0       6.0    1.0    19.0    Alabama     Cherokee County
# 11      50.0     3.0       6.0    1.0    21.0    Alabama      Chilton County
# ...

# %%
(df.where(df['SUMLEV']==50)).dropna().set_index(['STNAME','CTYNAME'])
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
(df.where(df['SUMLEV']==50)).dropna().set_index(['STNAME','CTYNAME']).rename(columns={'ESTIMATESBASE2010':'Estimate base 2010'})
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
# METHOD 2  Easy but non Pandorable

df=df[df['SUMLEV']==50]
df.set_index(['STNAME','CTYNAME'],inplace=True)
df.rename(columns={'ESTIMATESBASE2010':'Estimate base 2010'})
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County          50       3         6      1       1
#           Baldwin County          50       3         6      1       3
#           Barbour County          50       3         6      1       5
#           Bibb County             50       3         6      1       7
#           Blount County           50       3         6      1       9
#           Bullock County          50       3         6      1      11
#           Butler County           50       3         6      1      13
#           Calhoun County          50       3         6      1      15
#           Chambers County         50       3         6      1      17
#           Cherokee County         50       3         6      1      19
#           Chilton County          50       3         6      1      21
#           Choctaw County          50       3         6      1      23
# ...

# %% [markdown]
# ##  apply function

# %%
import numpy as np
import pandas as pd

# %%
def min_max(row):
    data=row[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']]
    return pd.Series( {'min':np.min(data),'max':np.max(data)} )

# %%
df.apply(min_max,axis=1)
# Out:
#                                    min       max
# STNAME    CTYNAME
# Alabama   Autauga County       54660.0   55347.0
#           Baldwin County      183193.0  203709.0
#           Barbour County       26489.0   27341.0
#           Bibb County          22512.0   22861.0
#           Blount County        57373.0   57776.0
#           Bullock County       10606.0   10887.0
#           Butler County        20154.0   20944.0
#           Calhoun County      115620.0  118437.0
#           Chambers County      33993.0   34153.0
#           Cherokee County      25859.0   26084.0
#           Chilton County       43665.0   43943.0
#           Choctaw County       13170.0   13841.0
#           Clarke County        24675.0   25767.0
#           Clay County          13456.0   13880.0
#           Cleburne County      14921.0   15072.0
#           Coffee County        50177.0   51211.0
#           Colbert County       54354.0   54514.0
#           Conecuh County       12662.0   13208.0
# ...

# %%
def min_max(row):
    data=row[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']]
    row['max']=np.max(data)
    row['min']=np.min(data)
    return row

# %%
rows=['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']
df.apply(min_max,axis=1)
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
df.apply(lambda x: np.max(x[rows]),axis=1)
# Out:
# STNAME     CTYNAME
# Alabama    Autauga County         55347.0
#            Baldwin County        203709.0
#            Barbour County         27341.0
#            Bibb County            22861.0
#            Blount County          57776.0
#            Bullock County         10887.0
#            Butler County          20944.0
#            Calhoun County        118437.0
#            Chambers County        34153.0
#            Cherokee County        26084.0
#            Chilton County         43943.0
#            Choctaw County         13841.0
#            Clarke County          25767.0
#            Clay County            13880.0
#            Cleburne County        15072.0
#            Coffee County          51211.0
#            Colbert County         54514.0
#            Conecuh County         13208.0
#            Coosa County           11758.0
#            Covington County       38060.0
#            Crenshaw County        13963.0
#            Cullman County         82005.0
# ...

# %%
rows
# Out:
# ['POPESTIMATE2010',
#  'POPESTIMATE2011',
#  'POPESTIMATE2012',
#  'POPESTIMATE2013',
#  'POPESTIMATE2014',
#  'POPESTIMATE2015']

# %% [markdown]
# ## Applying Lambda Example #2

# %%
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'), index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
# Out:
#                b         d         e
# Utah    1.157373 -1.316262 -0.019143
# Ohio    0.776749 -0.899427 -0.135955
# Texas  -1.156959 -0.185227  0.603641
# Oregon  0.408673  0.637161 -1.147497

# %%
frame.apply(lambda:x np.max(x[rows]),axis=1)
# Out:
#   File "<ipython-input-38-de93985aee07>", line 1
#     frame.apply(lambda:x np.max(x[rows]),axis=1)
#                           ^
# SyntaxError: invalid syntax

# %%
rows=['b','d','e']
frame.apply(lambda x: np.max(x[rows]),axis=1)

# %% [markdown]
# ### Lambda Example 3
# writing lamda seperatly as a function  and  then callung in apply()
#
# Here the function f, which computes the difference between the maximum and minimum
# of a Series, is invoked once on each row in frame. The result is a Series having
# the rows of frame as its index

# %%
f= lambda x: x.max()- x.min()

# %%
frame.apply(f,axis=1)

# %% [markdown]
# ### The function passed to apply need not return a scalar value; it can also return a Series with multiple values

# %%
def f(x):
    return pd.Series([x.min(),x.max()],index=['min','max'])

# %%
frame.apply(f,axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-78a7d71f953b> in <module>()
# ----> 1 frame.apply(f,axis=1)
#
# NameError: name 'f' is not defined

# %%
ff2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-6b8c53816814> in <module>()
# ----> 1 ff2
#
# NameError: name 'ff2' is not defined

# %% [markdown]
# ## Applymap( )
#
# #### Element-wise Python functions can be used, too. Suppose you wanted to compute a formatted string from each floating-point value in frame. You can do this with apply map:

# %%
# format = lambda x: '%.2f' % x
format=lambda x: '%.2f' %x
frame.applymap(format)
# Out:
#             b      d      e
# Utah     1.16  -1.32  -0.02
# Ohio     0.78  -0.90  -0.14
# Texas   -1.16  -0.19   0.60
# Oregon   0.41   0.64  -1.15

# %%
frame['e'].map(format)
# Out:
# Utah      -0.02
# Ohio      -0.14
# Texas      0.60
# Oregon    -1.15
# Name: e, dtype: object

# %% [markdown]
# ## Group by

# %%
df=pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df.groupby(['SUMLEV'])

# %%
df.groupby(['SUMLEV']).count()
# Out:
#         REGION  DIVISION  STATE  COUNTY  STNAME  CTYNAME  CENSUS2010POP  \
# SUMLEV
# 40          51        51     51      51      51       51             51
# 50        3142      3142   3142    3142    3142     3142           3142
#
#         ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011     ...       \
# SUMLEV                                                          ...
# 40                     51               51               51     ...
# 50                   3142             3142             3142     ...
#
#         RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# SUMLEV
# 40                    51                51                51
# 50                  3142              3142              3142
#
#         RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  \
# SUMLEV
# 40                    51                51           51           51
# 50                  3142              3142         3142         3142
#
# ...

# %%
# if we are not using groupby what we will do

# %%
# excluding the state level summarization
df=df[df['SUMLEV']==50]

# %%
# 1. find the unique
df['STNAME'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df.where(df['STNAME']=='West Virginia')
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY STNAME CTYNAME  CENSUS2010POP  \
# 1        NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 2        NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 3        NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 4        NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 5        NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 6        NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 7        NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 8        NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 9        NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 10       NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# 11       NaN     NaN       NaN    NaN     NaN    NaN     NaN            NaN
# ...

# %%
df[df['STNAME']=='West Virginia']
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY         STNAME  \
# 3041      50       3         5     54       1  West Virginia
# 3042      50       3         5     54       3  West Virginia
# 3043      50       3         5     54       5  West Virginia
# 3044      50       3         5     54       7  West Virginia
# 3045      50       3         5     54       9  West Virginia
# 3046      50       3         5     54      11  West Virginia
# 3047      50       3         5     54      13  West Virginia
# 3048      50       3         5     54      15  West Virginia
# 3049      50       3         5     54      17  West Virginia
# 3050      50       3         5     54      19  West Virginia
# 3051      50       3         5     54      21  West Virginia
# 3052      50       3         5     54      23  West Virginia
# 3053      50       3         5     54      25  West Virginia
# 3054      50       3         5     54      27  West Virginia
# ...

# %%
df[df['STNAME']=='West Virginia']['CENSUS2010POP']
# Out:
# 3041     16589
# 3042    104169
# 3043     24629
# 3044     14523
# 3045     24069
# 3046     96319
# 3047      7627
# 3048      9386
# 3049      8202
# 3050     46039
# 3051      8693
# 3052     11937
# 3053     35480
# 3054     23964
# 3055     30676
# 3056     14025
# 3057     69099
# 3058     29211
# 3059     53498
# 3060    193063
# 3061     16372
# 3062     21720
# 3063     36743
# 3064     22113
# 3065     56418
# 3066     33107
# 3067     27324
# 3068     62264
# 3069     28212
# 3070     26839
# 3071     96189
# 3072     13502
# 3073     17541
# 3074     26233
# 3075     44443
# 3076      7695
# 3077      7605
# 3078      8719
# 3079     33520
# 3080     55486
# 3081     78859
# 3082     29405
# 3083     10449
# 3084     14926
# 3085     13927
# 3086     16895
# 3087      7141
# 3088      9208
# 3089     24254
# 3090     42481
# 3091      9154
# 3092     16583
# 3093      5717
# 3094     86956
# 3095     23796
# Name: CENSUS2010POP, dtype: int64

# %%
np.average(df[df['STNAME']=='West Virginia']['CENSUS2010POP'])
# Out:
# 33690.8

# %%
# len(df[df['STNAME']==state]['CENSUS2010POP'])

# %%
for state in df['STNAME'].unique():
    avg=np.average(df[df['STNAME']==state]['CENSUS2010POP'])               # using df
    print('countries in state '+ state + 'has an average= '+ str(avg))
# Out:
# countries in state Alabamahas an average= 71339.34328358209
# countries in state Alaskahas an average= 24490.724137931036
# countries in state Arizonahas an average= 426134.4666666667
# countries in state Arkansashas an average= 38878.90666666667
# countries in state Californiahas an average= 642309.5862068966
# countries in state Coloradohas an average= 78581.1875
# countries in state Connecticuthas an average= 446762.125
# countries in state Delawarehas an average= 299311.3333333333
# countries in state District of Columbiahas an average= 601723.0
# countries in state Floridahas an average= 280616.5671641791
# countries in state Georgiahas an average= 60928.63522012578
# countries in state Hawaiihas an average= 272060.2
# countries in state Idahohas an average= 35626.86363636364
# countries in state Illinoishas an average= 125790.50980392157
# countries in state Indianahas an average= 70476.10869565218
# countries in state Iowahas an average= 30771.262626262625
# ...

# %% [markdown]
# ### using Groupby

# %%
# %%timeit -n 10
for state in df['STNAME'].unique():
    avg=np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('Countries in State' + state+ ' have an average population of '+str(avg))
# Out:
# Countries in StateAlabama have an average population of 71339.34328358209
# Countries in StateAlaska have an average population of 24490.724137931036
# Countries in StateArizona have an average population of 426134.4666666667
# Countries in StateArkansas have an average population of 38878.90666666667
# Countries in StateCalifornia have an average population of 642309.5862068966
# Countries in StateColorado have an average population of 78581.1875
# Countries in StateConnecticut have an average population of 446762.125
# Countries in StateDelaware have an average population of 299311.3333333333
# Countries in StateDistrict of Columbia have an average population of 601723.0
# Countries in StateFlorida have an average population of 280616.5671641791
# Countries in StateGeorgia have an average population of 60928.63522012578
# Countries in StateHawaii have an average population of 272060.2
# Countries in StateIdaho have an average population of 35626.86363636364
# ...

# %%
np.average(df['CENSUS2010POP'])
# Out:
# 98262.03564608529

# %%
# %%timeit -n 10
for group,frame in df.groupby('STNAME'):
    avg=np.average(frame['CENSUS2010POP'])
    print('Counties in state'+group+' have an average population of' +str(avg))
# Out:
# Counties in stateAlabama have an average population of71339.34328358209
# Counties in stateAlaska have an average population of24490.724137931036
# Counties in stateArizona have an average population of426134.4666666667
# Counties in stateArkansas have an average population of38878.90666666667
# Counties in stateCalifornia have an average population of642309.5862068966
# Counties in stateColorado have an average population of78581.1875
# Counties in stateConnecticut have an average population of446762.125
# Counties in stateDelaware have an average population of299311.3333333333
# Counties in stateDistrict of Columbia have an average population of601723.0
# Counties in stateFlorida have an average population of280616.5671641791
# Counties in stateGeorgia have an average population of60928.63522012578
# Counties in stateHawaii have an average population of272060.2
# Counties in stateIdaho have an average population of35626.86363636364
# ...

# %%
avg
# Out:
# 24505.478260869564

# %%
df.groupby('STNAME')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-158-87f015dbe6de> in <module>()
# ----> 1 df.groupby('STNAME')
#
# C:\ProgramData\Anaconda6\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# C:\ProgramData\Anaconda6\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# ...

# %% [markdown]
# ## from Book Python from Data Analysis

# %%
df

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data1' : np.random.randn(5),
                   'data2' : np.random.randn(5)})

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.426073  1.322781
# 1    a  two -1.932085  0.118485
# 2    b  one  0.634474  1.046087
# 3    b  two  1.540453  0.226612
# 4    a  one  0.316775  2.667430

# %%
df.groupby(df['key1'])

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped=df['data1'].groupby(df['key1'])
grouped

# %% [markdown]
# ### The idea is that this object has all of the information needed to then apply some operation to each of the groups.

# %%
grouped.mean()
# Out:
# key1
# a   -0.680461
# b    1.087463
# Name: data1, dtype: float64

# %%
grouped.count()
# Out:
# key1
# a    3
# b    2
# Name: data1, dtype: int64

# %% [markdown]
# ## The result index has the name 'key1' because the DataFrame column df['key1'] did.  If instead we had passed multiple arrays as a list, we’d get something different:

# %%
# df['data1'].groupby(df['key1']).mean()
mean=df['data1'].groupby([ df['key2'],df['key1']]).mean()
mean
# Out:
# key2  key1
# one   a      -0.054649
#       b       0.634474
# two   a      -1.932085
#       b       1.540453
# Name: data1, dtype: float64

# %%
df['data1'].groupby(df['key1']).mean()
# Out:
# key1
# a   -0.680461
# b    1.087463
# Name: data1, dtype: float64

# %%
mean.unstack()
# Out:
# key1         a         b
# key2
# one  -0.054649  0.634474
# two  -1.932085  1.540453

# %%
states=np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])
years = np.array([2005, 2005, 2006, 2005, 2006])

# %%
df['data1'].groupby([states, years]).mean()
# Out:
# California  2005   -1.932085
#             2006    0.634474
# Ohio        2005    0.557190
#             2006    0.316775
# Name: data1, dtype: float64

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.426073  1.322781
# 1    a  two -1.932085  0.118485
# 2    b  one  0.634474  1.046087
# 3    b  two  1.540453  0.226612
# 4    a  one  0.316775  2.667430

# %%
# we can give our custoom  key column of lenght same as dataframe
spake=np.array(['Oio', 'Cala', 'gal', 'Oh', 'io'])
nums = np.array([5, 2, 26, 1, 14])

# %%
df['data1'].groupby([spake, nums]).mean()
# Out:
# Cala  2    -1.932085
# Oh    1     1.540453
# Oio   5    -0.426073
# gal   26    0.634474
# io    14    0.316775
# Name: data1, dtype: float64

# %%
df.groupby(['key1', 'key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %% [markdown]
# ### Iterating Over Groups:The GroupBy object supports iteration, generating a sequence of 2-tuples containing the group name along with the chunk of data. Consider the following:

# %%
for name, group in df.groupby('key1'):
    print(name)
    print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one -0.426073  1.322781
# 1    a  two -1.932085  0.118485
# 4    a  one  0.316775  2.667430
# b
#   key1 key2     data1     data2
# 2    b  one  0.634474  1.046087
# 3    b  two  1.540453  0.226612

# %%
for (k1, k2), group in df.groupby(['key1', 'key2']):
    print((k1, k2))
    print(group)
# Out:
# ('a', 'one')
#   key1 key2     data1     data2
# 0    a  one -0.426073  1.322781
# 4    a  one  0.316775  2.667430
# ('a', 'two')
#   key1 key2     data1     data2
# 1    a  two -1.932085  0.118485
# ('b', 'one')
#   key1 key2     data1     data2
# 2    b  one  0.634474  1.046087
# ('b', 'two')
#   key1 key2     data1     data2
# 3    b  two  1.540453  0.226612

# %% [markdown]
# Of course, you can choose to do whatever you want with the pieces of data. A recipe
# you may find useful is computing a dict of the data pieces as a one-liner:

# %%
pieces = dict(list(df.groupby('key1')))
pieces
# Out:
# {'a':   key1 key2     data1     data2
#  0    a  one -0.426073  1.322781
#  1    a  two -1.932085  0.118485
#  4    a  one  0.316775  2.667430, 'b':   key1 key2     data1     data2
#  2    b  one  0.634474  1.046087
#  3    b  two  1.540453  0.226612}

# %%
piece=dict(list(df.groupby('key1')))
piece
# Out:
# {'a':   key1 key2     data1     data2
#  0    a  one -0.426073  1.322781
#  1    a  two -1.932085  0.118485
#  4    a  one  0.316775  2.667430, 'b':   key1 key2     data1     data2
#  2    b  one  0.634474  1.046087
#  3    b  two  1.540453  0.226612}

# %%
piece=dict(list(df.groupby(['key1','key2'])))
piece
# Out:
# {('a', 'one'):   key1 key2     data1     data2
#  0    a  one -0.426073  1.322781
#  4    a  one  0.316775  2.667430, ('a', 'two'):   key1 key2     data1     data2
#  1    a  two -1.932085  0.118485, ('b', 'one'):   key1 key2     data1     data2
#  2    b  one  0.634474  1.046087, ('b', 'two'):   key1 key2     data1     data2
#  3    b  two  1.540453  0.226612}

# %%
pieces['b']
# Out:
#   key1 key2     data1     data2
# 2    b  one  0.634474  1.046087
# 3    b  two  1.540453  0.226612

# %%
pieces
# Out:
# {'a':   key1 key2     data1     data2
#  0    a  one -0.426073  1.322781
#  1    a  two -1.932085  0.118485
#  4    a  one  0.316775  2.667430, 'b':   key1 key2     data1     data2
#  2    b  one  0.634474  1.046087
#  3    b  two  1.540453  0.226612}

# %%
pieces=dict(list(df.groupby('key1')))
pieces
# Out:
# {'a':   key1 key2     data1     data2
#  0    a  one -0.426073  1.322781
#  1    a  two -1.932085  0.118485
#  4    a  one  0.316775  2.667430, 'b':   key1 key2     data1     data2
#  2    b  one  0.634474  1.046087
#  3    b  two  1.540453  0.226612}

# %%
df.dtypes
# Out:
# key1      object
# key2      object
# data1    float64
# data2    float64
# dtype: object

# %%
s_grouped = df.groupby(['key1', 'key2'])['data2']

# %%
s_grouped

# %% [markdown]
# ## The object returned by this indexing operation is a grouped DataFrame if a list or array is passed or a grouped Series if only a single column name is passed as a scalar:

# %%
s_grouped = df.groupby(['key1', 'key2'])['data2']
s_grouped

# %%
s_grouped.mean()
# Out:
# key1  key2
# a     one     1.995105
#       two     0.118485
# b     one     1.046087
#       two     0.226612
# Name: data2, dtype: float64

# %% [markdown]
# ## Grouping with Dicts and Series
# Grouping information may exist in a form other than an array.

# %%
people = pd.DataFrame(np.random.randn(5, 5),
                     columns=['a', 'b', 'c', 'd', 'e'],
                     index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])

# %%
df=pd.read_csv('census.csv')

# %%
df=df[df['SUMLEV']==50]

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# 11        50       3         6      1      21    Alabama      Chilton County
# ...

# %%
df.groupby('STNAME').agg({'CENSUS2010POP':np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...
