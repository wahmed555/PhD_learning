# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('usefull_Election2018/NA Candidate List.csv')

# %%
df1
# Out:
#      District                     Seat Constituency_title  \
# 0     Chitral                  Chitral               NA-1
# 1     Chitral                  Chitral               NA-1
# 2     Chitral                  Chitral               NA-1
# 3     Chitral                  Chitral               NA-1
# 4     Chitral                  Chitral               NA-1
# 5     Chitral                  Chitral               NA-1
# 6     Chitral                  Chitral               NA-1
# 7     Chitral                  Chitral               NA-1
# 8     Chitral                  Chitral               NA-1
# 9     Chitral                  Chitral               NA-1
# 10    Chitral                  Chitral               NA-1
# 11       Swat                   Swat-I              NA-2
# 12       Swat                   Swat-I              NA-2
# 13       Swat                   Swat-I              NA-2
# 14       Swat                   Swat-I              NA-2
# ...

# %%
df1.iloc[10:30]
# Out:
#    District      Seat Constituency_title                Candidate_Name  \
# 10  Chitral   Chitral               NA-1                Nisar Dastager
# 11     Swat    Swat-I              NA-2                 Amjad Ali Khan
# 12     Swat    Swat-I              NA-2                     Amir Muqam
# 13     Swat    Swat-I              NA-2                Haider Ali Khan
# 14     Swat    Swat-I              NA-2                     Said Qamar
# 15     Swat    Swat-I              NA-2                 Ibadullah Khan
# 16     Swat    Swat-I              NA-2               Muhammad Mukhtar
# 17     Swat    Swat-I              NA-2                 Miraj Muhammad
# 18     Swat    Swat-I              NA-2      Malak Muhammad Didar Khan
# 19     Swat    Swat-I              NA-2                   Mumtaz Ahmad
# 20     Swat    Swat-I              NA-2                  Naveed lqbal
# 21     Swat   Swat-II               NA-3                  Aftab Shahid
# ...

# %%
df1['Party'].unique()
# Out:
# array(['Pakistan Muslim League(N)', 'Independent',
#        'Pakistan Rah-e-Haq Part',
#        'Pakistan Peoples Party Parliamentarians',
#        'Pakistan Tehreek-e-lnsaf', 'Awami National Party',
#        'All Pakistan Muslim League', 'Muttahida MAJLIS-E-AMAL PAKISTAN',
#        'Pashtoonkhwa Milli Avvami Party',
#        'Jamiat Ulmae Islam Nazryati Pakistan', 'Allah-o-Akbar Tehreek',
#        'Qaumi Watan Party', 'Tehreek Labbaik Pakistan',
#        'Pakistan Muslim League', 'Pak Sarzameen Party',
#        'Pakistan Muslim League (N)', 'MUTTHIDA MAJLIS-E-AMAL PAKlSTAN',
#        'MMA PAKISTAN', 'Pakistan Tehreek-e-Insaaf', 'Awami Workers Party',
#        'lndependent', 'Mutahidda Majlas E Amal',
#        'Pakistan Peoples Party Parlimentarian',
#        'MuTTHIDA MAJLIS E AMAL PAKISTAN', 'Pakistan Tehreek-e-Insaf\n',
#        'Allah-o-Akbar Tchreck', 'MUTTHIDA MAJLIS- E- AMAL PAKlSTAN',
#        'Tehreek Labbalk Pakistan', 'Humdardan-e-Watan Pakistan',
# ...

# %%
# df1['Constituency_title'].groupby()
grouped = df1['Seat'].groupby(df1['Party'])

# %% [raw]
# grouped

# %%
grouped.count()
# Out:
# Party
#                                             1
# ALL PAKISTAN MUSLIM LEAGUE                  1
# Aam Admi Tehreek Pakistan                   1
# Aam Awam Party                              2
# Aam Log Party Pakistan                      4
# All Pakistan Mishit) League                 1
# All Pakistan Muslim League                 33
# All Pakistan Muslim League                  6
# All Pakistan Muslim League (Jinnah)         1
# All Pakistan Muslim League(Jinnah)          1
# All Pakistan Muslim league                  1
# All Pakistan Tehreek                        1
# Allah o Akbar Tehreck                       1
# Allah o Akbar Tehreek                       5
# Allah o Akhbar Tehreek                      1
# Allah-O-Akbar Tehreek                      10
# Allah-o-Akbar Tchreck                       1
# Allah-o-Akbar Tehreek                      27
# Allah-o-Akbar Tehrook                       1
# Allah-o-Akber Tehreek                       9
# ...
